# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime

connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'test' , charset = 'utf8') 
cursor = connection.cursor()


# cursor.execute('SELECT `id` , `skill` FROM `test`.`cards_test` WHERE `skill_type_id` = 10')
# q = cursor.fetchall()

# for i in q:
#     line = i[1]
#     line = line[line.find('\n') + 1:]
#     per = line[: line.find('秒ごと')]
#     percent = line[line.find('に') + 1: line.find('の')-1 ]
#     cost = line[line.find('ライフを') + 4 : line.find('消費')]
#     bonus = line[line.find('ボーナスが') + 5: line.find('アップ')-1]
#     print(per)
#     print(percent)
#     print(cost)
#     print(bonus)
#     data = per + 'x' + percent + 'x' + cost + 'x' + bonus
#     print(data)
    
#     cursor.execute('UPDATE `test`.`cards_test` SET `skill` = %s WHERE `id` = %s' , (data , i[0]))



# cursor.execute('SELECT `id` , `skill` FROM `test`.`cards_test` WHERE `skill_type_id` = 9')
# q = cursor.fetchall()

# for i in q:
#     print(i[1])
#     line = i[1]
#     line = line[line.find('\n') + 1:]
#     per = line[: line.find('秒ごと')]
#     percent = line[line.find('に') + 1: line.find('の')-1 ]
# #     cost = line[line.find('ライフを') + 4 : line.find('消費')]
#     length = line[line.find('確率で') + 3 : line.find('秒間')]
#     bonus = line[line.find('スコアが') + 4: line.find('アップ')-1]
#     heal = line[line.find('ライフが') + 4: line.find('回復')]
#     print(per)
#     print(percent)
#     print(length)
#     print(bonus)
#     print(heal)
#     data = per + 'x' + percent + 'x' + length + 'x' + bonus + 'x' + heal
#     print(data)
    
#     cursor.execute('UPDATE `test`.`cards_test` SET `skill` = %s WHERE `id` = %s' , (data , i[0]))

# cursor.execute('SELECT `id` , `skill` FROM `test`.`cards_test` WHERE `skill_type_id` = 8')
# q = cursor.fetchall()

# for i in q:
#     print(i[1])
#     line = i[1]
#     line = line[line.find('\n') + 1:]
#     per = line[: line.find('秒ごと')]
#     percent = line[line.find('に') + 1: line.find('の')-1 ]
#     cost = line[line.find('ライフを') + 4 : line.find('消費')]
#     length = line[line.find('消費し') + 3 : line.find('秒間')]
#     bonus = line[line.find('スコアが') + 4: line.find('アップ')-1]
#     print(per)
#     print(percent)
#     print(cost)
#     print(length)
#     print(bonus)
#     data = per + 'x' + percent + 'x' + cost +'x' + length + 'x' + bonus
#     print(data)
    
#     cursor.execute('UPDATE `test`.`cards_test` SET `skill` = %s WHERE `id` = %s' , (data , i[0]))



# cursor.execute('SELECT `id` , `skill` FROM `test`.`cards_test` WHERE `skill_type_id` = 7')
# q = cursor.fetchall()

# for i in q:
#     print(i[1])
#     line = i[1]
#     line = line[line.find('\n') + 1:]
#     per = line[: line.find('秒ごと')]
#     percent = line[line.find('に') + 1: line.find('の')-1 ]
#     length = line[line.find('確率で') + 3 : line.find('秒間')]
#     bonus = line[line.find('スコアが') + 4: line.find('アップ')-1]
#     bonus2 = line[line.find('ボーナスが') + 5: line.rfind('アップ') -1]
#     print(per)
#     print(percent)
#     print(length)
#     print(bonus)
#     print(bonus2)
#     data = per + 'x' + percent + 'x' + length + 'x' + bonus + 'x' + bonus2
#     print(data)
    
#     cursor.execute('UPDATE `test`.`cards_test` SET `skill` = %s WHERE `id` = %s' , (data , i[0]))



# cursor.execute('SELECT `id` , `skill` FROM `test`.`cards_test` WHERE `skill_type_id` = 6')
# q = cursor.fetchall()

# for i in q:
# #     print(i[1])
#     line = i[1]
#     line = line[line.find('\n') + 1:]
# #     line = line[line.find('\n') + 1:]
# #     print(line)
#     per = line[line.find('秒ごと') - 1: line.find('秒ごと')]
#     line = line[line.find('秒ごと'):]
#     print(line)
#     percent = line[line.find('に') + 1: line.find('の')-1 ]
#     length = line[line.find('確率で') + 3 : line.find('秒間')]
# #     bonus = line[line.find('スコアが') + 4: line.find('アップ')-1]
# #     bonus2 = line[line.find('ボーナスが') + 5: line.rfind('アップ') -1]
#     print(per)
#     print(percent)
#     print(length)
# #     print(bonus)
# #     print(bonus2)
#     data = per + 'x' + percent + 'x' + length 
# #     print(data)
    
#     cursor.execute('UPDATE `test`.`cards_test` SET `skill` = %s WHERE `id` = %s' , (data , i[0]))



# cursor.execute('SELECT `id` , `skill` FROM `test`.`cards_test` WHERE `skill_type_id` = 5')
# q = cursor.fetchall()

# for i in q:
# #     print(i[1])
#     line = i[1]
#     line = line[line.find('秒ごと') -5:]
#     line = line[line.find('\n') + 1:]
    
#     print(line)
#     per = line[: line.find('秒ごと')]
#     percent = line[line.find('に') + 1: line.find('の')-1 ]
#     length = line[line.find('確率で') + 3 : line.find('秒間')]
# #     bonus = line[line.find('スコアが') + 4: line.find('アップ')-1]
# #     bonus2 = line[line.find('ボーナスが') + 5: line.rfind('アップ') -1]
#     print(per)
#     print(percent)
#     print(length)
# #     print(bonus)
# #     print(bonus2)
#     data = per + 'x' + percent + 'x' + length 
#     print(data)
    
#     cursor.execute('UPDATE `test`.`cards_test` SET `skill` = %s WHERE `id` = %s' , (data , i[0]))




# cursor.execute('SELECT `id` , `skill` FROM `test`.`cards_test` WHERE `skill_type_id` = 4')
# q = cursor.fetchall()

# for i in q:
# #     print(i[1])
#     line = i[1]
#     line = line[line.find('秒ごと') -5:]
#     line = line[line.find('\n') + 1:]
    
#     print(line)
#     per = line[: line.find('秒ごと')]
#     percent = line[line.find('に') + 1: line.find('の')-1 ]
#     length = line[line.find('確率で') + 3 : line.find('秒間')]
#     heal = line[line.find('ライフが') + 4 : line.find('回復')]
# # #     bonus = line[line.find('スコアが') + 4: line.find('アップ')-1]
# # #     bonus2 = line[line.find('ボーナスが') + 5: line.rfind('アップ') -1]
#     print(per)
#     print(percent)
#     print(length)
#     print(heal)
# # #     print(bonus)
# # #     print(bonus2)
#     data = per + 'x' + percent + 'x' + length  + 'x' + heal
#     print(data)
    
#     cursor.execute('UPDATE `test`.`cards_test` SET `skill` = %s WHERE `id` = %s' , (data , i[0]))





# cursor.execute('SELECT `id` , `skill` FROM `test`.`cards_test` WHERE `skill_type_id` = 3')
# q = cursor.fetchall()

# for i in q:
#     line = i[1]
#     line = line[line.find('秒ごと') -5:]
#     line = line[line.find('\n') + 1:]
    
#     print(line)
#     per = line[: line.find('秒ごと')]
#     percent = line[line.find('に') + 1: line.find('の')-1 ]
#     length = line[line.find('確率で') + 3 : line.find('秒間')]
# #     heal = line[line.find('ライフが') + 4 : line.find('回復')]
#     bonus = line[line.find('スコアが') + 4: line.find('アップ')-1]
# #     bonus2 = line[line.find('ボーナスが') + 5: line.rfind('アップ') -1]
#     print(per)
#     print(percent)
#     print(length)
# #     print(heal)
#     print(bonus)
# #     print(bonus2)
#     data = per + 'x' + percent + 'x' + length + 'x' + bonus
#     print(data)
    
#     cursor.execute('UPDATE `test`.`cards_test` SET `skill` = %s WHERE `id` = %s' , (data , i[0]))



# cursor.execute('SELECT `id` , `skill` FROM `test`.`cards_test` WHERE `skill_type_id` = 2')
# q = cursor.fetchall()

# for i in q:
#     line = i[1]
#     line = line[line.find('秒ごと') -5:]
#     line = line[line.find('\n') + 1:]
    
#     print(line)
#     per = line[: line.find('秒ごと')]
#     percent = line[line.find('に') + 1: line.find('の')-1 ]
#     length = line[line.find('確率で') + 3 : line.find('秒間')]
# # #     heal = line[line.find('ライフが') + 4 : line.find('回復')]
# #     bonus = line[line.find('スコアが') + 4: line.find('アップ')-1]
# # #     bonus2 = line[line.find('ボーナスが') + 5: line.rfind('アップ') -1]
#     print(per)
#     print(percent)
#     print(length)
# # #     print(heal)
# #     print(bonus)
# # #     print(bonus2)
#     data = per + 'x' + percent + 'x' + length
#     print(data)
    
#     cursor.execute('UPDATE `test`.`cards_test` SET `skill` = %s WHERE `id` = %s' , (data , i[0]))




# cursor.execute('SELECT `id` , `skill` FROM `test`.`cards_test` WHERE `skill_type_id` = 1')
# q = cursor.fetchall()

# for i in q:
#     line = i[1]
#     line = line[line.find('秒ごと') -5:]
#     line = line[line.find('\n') + 1:]
    
#     print(line)
#     per = line[: line.find('秒ごと')]
#     percent = line[line.find('に') + 1: line.find('の')-1 ]
#     length = line[line.find('確率で') + 3 : line.find('秒間')]
# # # #     heal = line[line.find('ライフが') + 4 : line.find('回復')]
# # #     bonus = line[line.find('スコアが') + 4: line.find('アップ')-1]
#     bonus2 = line[line.find('ボーナスが') + 5: line.rfind('アップ') -1]
#     print(per)
#     print(percent)
#     print(length)
# # # #     print(heal)
# # #     print(bonus)
#     print(bonus2)
#     data = per + 'x' + percent + 'x' + length + 'x' + bonus2
#     print(data)
    
#     cursor.execute('UPDATE `test`.`cards_test` SET `skill` = %s WHERE `id` = %s' , (data , i[0]))



connection.commit()
cursor.close()
connection.close()
time2 = datetime.datetime.now()
print(time2)
print('papara')
# Out:
# 9秒ごとに31%の確率で6秒間、コンボボーナスが14％アップ
#
#
#
# 9
# 31
# 6
# 14
# 9x31x6x14
# 9秒ごとに31%の確率で6秒間、コンボボーナスが14％アップ
#
#
#
# 9
# 31
# 6
# 14
# 9x31x6x14
# 9秒ごとに31％の確率で6秒間、コンボボーナスが14%アップ
#
#
#
# 9
# 31
# 6
# 14
# 9x31x6x14
# 9秒ごとに31％の確率で6秒間、コンボボーナスが14%アップ
#
#
#
# 9
# 31
# 6
# 14
# 9x31x6x14
# 9秒ごとに31%の確率で6秒間、コンボボーナスが14%アップ
#
#
#
# 9
# 31
# 6
# 14
# 9x31x6x14
# 9秒ごとに31%の確率で6秒間、コンボボーナスが14%アップ
#
#
#
# 9
# 31
# 6
# 14
# 9x31x6x14
# 7秒ごとに31％の確率で5秒間、コンボボーナスが14％アップ
#
#
#
# 7
# 31
# 5
# 14
# 7x31x5x14
# 7秒ごとに31％の確率で5秒間、コンボボーナスが14％アップ
#
#
#
# 7
# 31
# 5
# 14
# 7x31x5x14
# 9秒ごとに31%の確率で5秒間、コンボボーナスが26%アップ
#
#
#
# 9
# 31
# 5
# 26
# 9x31x5x26
# 9秒ごとに31%の確率で5秒間、コンボボーナスが26%アップ
#
#
#
# 9
# 31
# 5
# 26
# 9x31x5x26
# 11秒ごとに31%の確率で6秒間、コンボボーナスが26%アップ
#
#
#
# 11
# 31
# 6
# 26
# 11x31x6x26
# 11秒ごとに31%の確率で6秒間、コンボボーナスが26%アップ
#
#
#
# 11
# 31
# 6
# 26
# 11x31x6x26
# 13秒ごとに31%の確率で7秒間、コンボボーナスが20%アップ
#
#
#
# 13
# 31
# 7
# 20
# 13x31x7x20
# 13秒ごとに31%の確率で7秒間、コンボボーナスが20%アップ
#
#
#
# 13
# 31
# 7
# 20
# 13x31x7x20
# ...
