# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup

connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587" , db = 'test' , charset = 'utf8') 

cursor = connection.cursor()

cursor.execute('SELECT * FROM test.idols')

q = cursor.fetchall()

for i in range(0 , 54):
    print(q[i])
    name = q[i][2]
    cursor.execute('UPDATE `test`.`cards` SET `idol_id` = %s WHERE `idol` = %s' , (i + 1 , name , ))

    










connection.commit()
cursor.close()
connection.close()

print('s')
# Out:
# (1, '天海春香', '天海春香', 'PRINCESS', None, None)
# (2, 'エミリー', 'エミリー', 'PRINCESS', None, None)
# (3, '春日未来', '春日未来', 'PRINCESS', None, None)
# (4, '我那覇響', '我那覇響', 'PRINCESS', None, None)
# (5, '菊地真', '菊地真', 'PRINCESS', None, None)
# (6, '高坂海美', '高坂海美', 'PRINCESS', None, None)
# (7, '佐竹美奈子', '佐竹美奈子', 'PRINCESS', None, None)
# (8, '高山紗代子', '高山紗代子', 'PRINCESS', None, None)
# (9, '田中琴葉', '田中琴葉', 'PRINCESS', None, None)
# (10, '徳川まつり', '徳川まつり', 'PRINCESS', None, None)
# (11, '中谷育', '中谷育', 'PRINCESS', None, None)
# (12, '七尾百合子', '七尾百合子', 'PRINCESS', None, None)
# (13, '萩原雪歩', '萩原雪歩', 'PRINCESS', None, None)
# (14, '福田のり子', '福田のり子', 'PRINCESS', None, None)
# (15, '松田亜利沙', '松田亜利沙', 'PRINCESS', None, None)
# (16, '矢吹可奈', '矢吹可奈', 'PRINCESS', None, None)
# (17, '横山奈緒', '横山奈緒', 'PRINCESS', None, None)
# (18, '秋月律子', '秋月律子', 'FAIRY', None, None)
# (19, '如月千早', '如月千早', 'FAIRY', None, None)
# (20, '北沢志保', '北沢志保', 'FAIRY', None, None)
# (21, '四条貴音', '四条貴音', 'FAIRY', None, None)
# (22, 'ジュリア', 'ジュリア', 'FAIRY', None, None)
# (23, '白石紬', '白石紬', 'FAIRY', None, None)
# (24, '周防桃子', '周防桃子', 'FAIRY', None, None)
# (25, '天空橋朋花', '天空橋朋花', 'FAIRY', None, None)
# (26, '所恵美', '所恵美', 'FAIRY', None, None)
# (27, '永吉昴', '永吉昴', 'FAIRY', None, None)
# (28, '二階堂千鶴', '二階堂千鶴', 'FAIRY', None, None)
# (29, '舞浜歩', '舞浜歩', 'FAIRY', None, None)
# (30, '真壁瑞希', '真壁瑞希', 'FAIRY', None, None)
# (31, '水瀬伊織', '水瀬伊織', 'FAIRY', None, None)
# (32, '最上静香', '最上静香', 'FAIRY', None, None)
# (33, '百瀬莉緒', '百瀬莉緒', 'FAIRY', None, None)
# (34, 'ロコ', 'ロコ', 'FAIRY', None, None)
# (35, '伊吹翼', '伊吹翼', 'ANGEL', None, None)
# (36, '大神環', '大神環', 'ANGEL', None, None)
# (37, '北上麗花', '北上麗花', 'ANGEL', None, None)
# (38, '木下ひなた', '木下ひなた', 'ANGEL', None, None)
# (39, '桜守歌織', '桜守歌織', 'ANGEL', None, None)
# (40, '篠宮可憐', '篠宮可憐', 'ANGEL', None, None)
# (41, '島原エレナ', '島原エレナ', 'ANGEL', None, None)
# (42, '高槻やよい', '高槻やよい', 'ANGEL', None, None)
# (43, '豊川風花', '豊川風花', 'ANGEL', None, None)
# (44, '野々原茜', '野々原茜', 'ANGEL', None, None)
# (45, '箱崎星梨花', '箱崎星梨花', 'ANGEL', None, None)
# (46, '馬場このみ', '馬場このみ', 'ANGEL', None, None)
# (47, '双海亜美', '双海亜美', 'ANGEL', None, None)
# (48, '双海真美', '双海真美', 'ANGEL', None, None)
# (49, '星井美希', '星井美希', 'ANGEL', None, None)
# (50, '三浦あずさ', '三浦あずさ', 'ANGEL', None, None)
# (51, '宮尾美也', '宮尾美也', 'ANGEL', None, None)
# (52, '望月杏奈', '望月杏奈', 'ANGEL', None, None)
# (53, '詩花', '詩花', 'EX', None, None)
# (54, '玲音', '玲音', 'EX', None, None)
# s
