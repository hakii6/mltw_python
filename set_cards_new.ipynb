# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime

time1 = datetime.datetime.now()



connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'test' , charset = 'utf8') 
cursor = connection.cursor()

# cursor.execute('SELECT * FROM `test`.`cards_test` WHERE 1')
# q = cursor.fetchall()

# cursor.execute('TRUNCATE TABLE `test`.`cards_test_2`')


def set_card(cardA , cardB):
    
    complete = 1
    
    card_id = (cardA[0] + 1) / 2
    idol_id = cardA[1]
    name_jp = cardA[2]
    name_tw = cardA[3]
    rarity = cardA[4]
    total = cardB[5]
    vocal = cardB[6]
    dance = cardB[7]
    visual = cardB[8]
    center_skill_id = cardA[9]
    skill = cardA[10]
    skill_type_id = cardA[11]
    date = cardA[12]
    image = cardA[13]
    limited = cardA[16]
    master = cardA[17]
    get_card_id = cardA[18]
    get_card_type = cardA[19]
    
    cursor.execute('''INSERT INTO `test`.`cards_test_2`(
    `id` , `idol_id` , `name_jp` , `name_tw` , `rarity` ,
    `total` , `vocal` , `dance` , `visual` ,
    `center_skill_id` , `skill` , `skill_type_id` ,
    `date` , `image` ,
    `limited` , `master` , 
    `get_card_id` , `get_card_type` , `complete`
    ) VALUES(
    # %s , %s , %s , %s , %s ,
    # %s , %s , %s , %s ,
    # %s , %s , %s ,
    # %s , %s , 
    # %s , %s , 
    # %s , %s , %s
    )
    ''' , (
    card_id , idol_id , name_jp , name_tw , rarity,
    total , vocal , dance , visual,
    center_skill_id , skill , skill_type_id ,
    date , image ,
    limited , master , 
    get_card_id , get_card_type , complete))
    
    
    
def set_card_2(card):
    
    complete = 0
    
    if card[0] % 2 == 1:
    
        card_id = (card[0] + 1) / 2
        idol_id = card[1]
        name_jp = card[2]
        name_tw = card[3]
        rarity = card[4]
        total = 0
        vocal = 0
        dance = 0
        visual = 0
        center_skill_id = card[9]
        skill = card[10]
        skill_type_id = card[11]
        date = card[12]
        image = card[13]
        limited = card[16]
        master = card[17]
        get_card_id = card[18]
        get_card_type = card[19]
        
    else:
        
        card_id = card[0]  / 2
        idol_id = card[1]
        name_jp = card[2][:len(card[2]) - 1]
        name_tw = card[3][:len(card[3]) - 1]
        rarity = card[4][:len(card[4]) - 1]
        total = card[5]
        vocal = card[6]
        dance = card[7]
        visual = card[8]
        center_skill_id = card[9]
        skill = card[10]
        skill_type_id = card[11]
        date = card[12]
        image = card[13]
        limited = card[16]
        master = card[17]
        get_card_id = 0
        get_card_type = "0"     
    
    
    
    

    
    cursor.execute('''INSERT INTO `test`.`cards_test_2`(
    `id` , `idol_id` , `name_jp` , `name_tw` , `rarity` ,
    `total` , `vocal` , `dance` , `visual` ,
    `center_skill_id` , `skill` , `skill_type_id` ,
    `date` , `image` ,
    `limited` , `master` , 
    `get_card_id` , `get_card_type` , `complete`
    ) VALUES(
    # %s , %s , %s , %s , %s ,
    # %s , %s , %s , %s ,
    # %s , %s , %s ,
    # %s , %s , 
    # %s , %s , 
    # %s , %s , %s
    )
    ''' , (
    card_id , idol_id , name_jp , name_tw , rarity,
    total , vocal , dance , visual,
    center_skill_id , skill , skill_type_id ,
    date , image ,
    limited , master , 
    get_card_id , get_card_type , complete))  
    
    
    

count = 0
cards = []
for count in range(0 , 900):
    
    cursor.execute('SELECT * FROM `test`.`cards_test` WHERE `id` = %s OR `id` = %s' , (2 * count + 1, 2 * count + 2))
    q = cursor.fetchall()    
    if(q):
        cards.append(q)

for i in cards:
    if(len(i) != 2):
        set_card_2(i[0])
    else:
        set_card(i[0] , i[1])
        







connection.commit()
cursor.close()
connection.close()
time2 = datetime.datetime.now()
print(time1)
print(time2)
print('papara')
# Out:
# 517.0 12 クランクアップ！　七尾百合子 クランクアップ！　七尾百合子 SR 13723 5226 3893 4604 3 9x31x5x26 3 2021.04.01 https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/wikidb_thumbnail/937989/individual_200.jpg?d=20190405012940&q=20 .01
#
#
#
#  0 0 0
# 518.0 8 記念スナップ　高山紗代子 記念スナップ　高山紗代子 SR 13734 3869 5271 4594 7 6x31x3x3 4 2021.04.01 https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/wikidb_thumbnail/937990/individual_200.jpg?d=20190405022057&q=20 .01
#
#
#
#  0 0 0
# 682.0 34 超ビーチバレー［プチキング］　ロコ 超ビーチバレー［プチキング］　ROCO SR 13756 4618 3204 5934 9 11x36x5x26 3 2021.09.22 https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/wikidb_thumbnail/968082/individual_200.jpg?d=20191222205550&q=20 .22
#
#
#
#  0 0 0
# 683.0 20 三姉妹カフェ［黒ネコ］　北沢志保 三姉妹カフェ［黒ネコ］　北澤志保 SR 13787 3232 4588 5967 9 11x31x6x26 3 2021.09.22 https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/wikidb_thumbnail/968083/individual_200.jpg?d=20191222205617&q=20 .22
#
#
#
#  0 0 0
# ...

# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime

time1 = datetime.datetime.now()



connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'test' , charset = 'utf8') 
cursor = connection.cursor()
cursor.execute('TRUNCATE TABLE `test`.`images`')



cursor.execute('SELECT `id` , `image` FROM `test`.`cards_test` WHERE 1')
q = cursor.fetchall()

count = 0

for i in q:
    print(i)
    count = count + 1
    
    image_id = count
    card_id = int ((i[0] + 1) / 2)
    image = i[1]
    image_type = (i[0] + 1) % 2 
    cursor.execute('INSERT INTO `test`.`images`(`id` , `card_id` , `image` , `type`) VALUES (%s , %s , %s , %s)' ,
                  (image_id , card_id , image , str(image_type)))
    
    
    
connection.commit()
cursor.close()
connection.close()
time2 = datetime.datetime.now()
print(time1)
print(time2)
print('papara')
# Out:
# (1, 'https://i.imgur.com/WK0LM99.jpg')
# (2, 'https://i.imgur.com/efmvPPy.jpg')
# (3, 'https://i.imgur.com/tvXluZK.jpg')
# (4, 'https://i.imgur.com/IWnPRqj.jpg')
# (5, 'https://i.imgur.com/x6cw95z.jpg')
# (6, 'https://i.imgur.com/K4hmFgA.jpg')
# (7, 'https://i.imgur.com/woZg9Su.jpg')
# (8, 'https://i.imgur.com/UaPzw9Z.jpg')
# (9, 'https://i.imgur.com/gn2nvOr.jpg')
# (10, 'https://i.imgur.com/nm0AUuC.jpg')
# (11, 'https://i.imgur.com/Q7VOiu8.jpg')
# (12, 'https://i.imgur.com/ebgONVx.jpg')
# (13, 'https://i.imgur.com/dSlTu0W.jpg')
# (14, 'https://i.imgur.com/hEdkfZK.jpg')
# (15, 'https://i.imgur.com/SAwIwwy.jpg')
# (16, 'https://i.imgur.com/RCFfhJG.jpg')
# (17, 'https://i.imgur.com/XgZURk8.jpg')
# (18, 'https://i.imgur.com/Xbcd8jO.jpg')
# (19, 'https://i.imgur.com/4StN4Nq.jpg')
# (20, 'https://i.imgur.com/SXRl4UK.jpg')
# (21, 'https://i.imgur.com/AJNL56F.jpg')
# (22, 'https://i.imgur.com/zVPdzUf.jpg')
# (23, 'https://i.imgur.com/8KuV4ow.jpg')
# (24, 'https://i.imgur.com/J9O2qkO.jpg')
# ...
