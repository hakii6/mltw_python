# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from urllib.parse import unquote

from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime

start_time = datetime.datetime.now()



connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'mltd' , charset = 'utf8') 
cursor = connection.cursor()
cursor.execute('TRUNCATE TABLE `test`.`events_2020`')



    

        
        
def get_url(hp):
    
    req = requests.get(hp)
    bs = BeautifulSoup(req.text , 'lxml')

    table = bs.select('tbody')[0]
    data = table.select('td')
    flag = 0
    count = 400
    for i in data:
        if(i['data-col'] == '1' and flag == 1):
            date = i.text
            start_date = date[:date.find(')')-2]
            date = date[date.find(')'):]
            end_date = date[date.find('20'):date.rfind(')')-2]
            if(len(end_date) == 0):
                end_date = start_date

            
        if(i['data-col'] == '0' ):
            img = i.select('img')
            if(len(img) == 0):
                flag = 1
                temp = i.select('a')[0]
                ori_url = temp['href'] #url
                
                ori_url = urllib.parse.unquote(ori_url)    #utf-8
                name_jp = temp.text #name
            else:
                count = count + 1
                flag = 0
                image = img[0]['data-original'] #image
                
                print(name_jp)
                print(start_date)
                print(end_date)                
                print(image)
                print(ori_url)
                
                
                
                q = cursor.execute('INSERT into `test`.`events_2020`(`id` , `name_jp` , `name_tw` , `start_date` , `end_date` , `image` , `ori_url`) VALUES(%s , %s, %s , %s , %s , %s , %s)' ,
                    (count , name_jp , name_jp , start_date , end_date , image , ori_url))
    
    
        
    
    

        
        
        
        
        
homepage_2020 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7'
get_url(homepage_2020)



print('')
print(start_time)
print(datetime.datetime.now())

connection.commit()
cursor.close()
connection.close()
print('papara')
# Out:
# プラチナスターシアター～アライブファクター～
# 2020/05/31
# 2020/06/08
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1590905686.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターシアター～アライブファクター～
# MILLION LIVE WORKING☆
# ～大ヒット！アイドル商品開発部～
# 2020/05/27
# 2020/05/30
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1590559802.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】MILLION LIVE WORKING☆～大ヒット！アイドル商品開発部～
# プラチナスターツアー～絶対的Performer～
# 2020/05/18
# 2020/05/25
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1589782278.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターツアー～絶対的Performer～
# ミリコレ！～MILLIONLIVE COLLECTION～
# 2020/05/11
# 2020/05/16
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1589178709.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】ミリコレ！～MILLIONLIVE COLLECTION～ 202005
# プラチナスターシアター～Bigバルーン◎～
# 2020/05/02
# 2020/05/09
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1588400052.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターシアター～Bigバルーン◎～
# MILLION LIVE WORKING☆
# ～大合奏！アイドルシンフォニー～
# 2020/04/28
# 2020/05/01
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1588054762.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】MILLION LIVE WORKING☆～大合奏！アイドルシンフォニー～
# プラチナスターツアー～クルリウタ～
# 2020/04/19
# 2020/04/26
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1587277354.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターツアー～クルリウタ～
# ミリコレ！～MILLIONLIVE COLLECTION～
# 2020/04/11
# 2020/04/17
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1586588775.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】ミリコレ！～MILLIONLIVE COLLECTION～ 202004
# プラチナスターシアター～Helloコンチェルト～
# 2020/04/02
# 2020/04/09
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1585807663.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターシアター～Helloコンチェルト～
# 超ビーチバレー ～超全国大会編～
# 2020/04/01
# 2020/04/01
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1585667369.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】2020年エイプリルフールイベント
# MILLION LIVE WORKING☆
# ～もっと！輝け！アイドル強化合宿～
# 2020/03/27
# 2020/03/31
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1585289350.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】MILLION LIVE WORKING☆～もっと！輝け！アイドル強化合宿～
# プラチナスターツインステージ
# ～深淵の蒼、熱焔の緋～
# 2020/03/18
# 2020/03/25
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1584517952001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターツインステージ～深淵の蒼、熱焔の緋～
# ミリコレ！～MILLIONLIVE COLLECTION～
# 2020/03/11
# 2020/03/16
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1583907024.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】ミリコレ！～MILLIONLIVE COLLECTION～ 202003
# プラチナスターシアター～Beat the World!!!～
# 2020/03/02
# 2020/03/09
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1583129394.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターシアター～Beat the World！！！～
# MILLION LIVE WORKING☆
# ～期間限定★アイドルカフェ～
# 2020/02/27
# 2020/03/01
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1582783674.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】MILLION LIVE WORKING☆～期間限定★アイドルカフェ～
# プラチナスターツアー～Super Duper～
# 2020/02/18
# 2020/02/25
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1582006354.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターツアー～Super Duper～
# ミリコレ！～MILLIONLIVE COLLECTION～
# 2020/02/11
# 2020/02/16
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1581401534.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】ミリコレ！～MILLIONLIVE COLLECTION～ 202002
# プラチナスターシアター
# ～メメント？モメント♪ルルルルル☆～
# 2020/02/02
# 2020/02/09
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1580626383.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターシアター～メメント？モメント♪ルルルルル☆～
# MILLION LIVE WORKING☆
# ～潜入！スパイシスターズ～
# 2020/01/29
# 2020/02/01
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1580279254.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】MILLION LIVE WORKING☆～潜入！スパイシスターズ～
# プラチナスターツアー～百花は月下に散りぬるを～
# 2020/01/20
# 2020/01/27
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1579504007.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターツアー～百花は月下に散りぬるを～
# ミリコレ！～MILLIONLIVE COLLECTION～
# 2020/01/12
# 2020/01/18
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1578809391.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】ミリコレ！～MILLIONLIVE COLLECTION～ 202001
# プラチナスターシアター～俠気乱舞～
# 2020/01/02
# 2020/01/10
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1577944874.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターシアター～俠気乱舞～
# MILLION LIVE WORKING☆ SPECIAL
# ～夢いっぱい！メルヘンアイドル物語～
# 2019/12/26
# 2020/01/01
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1577344916.jpg
# https://imasml-theater-wiki.gamerch.com/MILLION LIVE WORKING☆ SPECIAL～夢いっぱい！メルヘンアイドル物語～
#
# 2020-06-06 17:04:56.545845
# 2020-06-06 17:04:58.004928
# papara
