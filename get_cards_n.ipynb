# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime

time1 = datetime.datetime.now()



connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'test' , charset = 'utf8') 
cursor = connection.cursor()
cursor.execute('TRUNCATE TABLE `test`.`cards_n`')



def get_data(url , image):
    
    name = url[1:]
    
    req = requests.get(url)
    bs = BeautifulSoup(req.text , 'lxml')
    
    temp = bs.select('.ui_wikidb_top_area')
    content = temp[0].text
    
    content = content[content.find('キャラ') + 4 :]
    idol = content[:content.find('\n')]
    
    content = content[content.find('カード番号') + 6 :]
    number = int(content[:content.find('\n')])
    
    
    
    temp = bs.select('.ui_wikidb_middle_area')
    content = temp[0].text
    
    content = content[content.find('最大合計値') + 6:]
    total = content[: content.find('\n')]
    total = total.replace(',' , '')
    
    content = content[content.find('最大ダンス') + 6:]
    dance = content[:content.find('\n')]
    dance = dance.replace(',' , '')
    
    content = content[content.find('最大ボーカル') + 7:]
    vocal = content[:content.find('\n')]
    vocal = vocal.replace(',' , '')
    
    content = content[content.find('最大ビジュアル') + 8:]
    visual = content[:content.find('\n')]
    visual = visual.replace(',' , '')
    print(content)


    q = cursor.execute('''INSERT INTO `test`.`cards_n`(`id` , `name_jp` , `name_tw` , `idol` , 
    `total` , `dance` , `vocal` , `visual` , `date` , `image` , `ori_url`) 
    VALUES (%s , %s , %s , %s,
    # %s , %s , %s , %s , %s , %s , %s)''' , 
    (number , name , name , idol,
    total , dance , vocal , visual , '2017-06-29' , image , url))







def get_url(url):
    
    req = requests.get(url)
    bs = BeautifulSoup(req.text , 'lxml')
    homepage = 'https://imasml-theater-wiki.gamerch.com'
    
    
    temp = bs.select('.no-min-width')
    
    for i in temp:
        if i['data-col'] == '0':
            line = i.select('a')
            if len(line) != 0:
                line = line[0]
                img = line.select('img')[0]
                image = img['data-original']
                get_data(homepage + line['href'] , image)
    
    
    
    
                

homepage_N = 'https://imasml-theater-wiki.gamerch.com/N'
get_url(homepage_N)

connection.commit()
cursor.close()
connection.close()
time2 = datetime.datetime.now()
print(time1)
print(time2)
print('papara')
# Out:
# 1,718
# マスター最大ボーカル 2,684
# マスター最大ビジュアル 2,026
#
# 1,196
# マスター最大ボーカル 2,836
# マスター最大ビジュアル 1,412
#
# 2,304
# マスター最大ボーカル 2,044
# マスター最大ビジュアル 2,720
#
# 1,826
# マスター最大ボーカル 2,066
# マスター最大ビジュアル 2,154
#
# 1,868
# マスター最大ボーカル 1,852
# マスター最大ビジュアル 2,204
#
# 1,818
# マスター最大ボーカル 1,606
# マスター最大ビジュアル 2,146
#
# 1,804
# マスター最大ボーカル 2,116
# マスター最大ビジュアル 2,128
#
# 1,842
# マスター最大ボーカル 2,768
# マスター最大ビジュアル 2,174
#
# 1,766
# マスター最大ボーカル 1,578
# マスター最大ビジュアル 2,086
#
# 1,786
# マスター最大ボーカル 2,656
# マスター最大ビジュアル 2,106
#
# 1,798
# マスター最大ボーカル 2,046
# マスター最大ビジュアル 2,122
#
# 1,716
# マスター最大ボーカル 2,148
# マスター最大ビジュアル 2,024
#
# 1,240
# マスター最大ボーカル 2,106
# マスター最大ビジュアル 1,464
#
# 1,818
# マスター最大ボーカル 2,146
# マスター最大ビジュアル 2,146
#
# 1,870
# マスター最大ボーカル 2,658
# マスター最大ビジュアル 2,206
#
# 2,162
# マスター最大ボーカル 1,916
# マスター最大ビジュアル 2,550
#
# 1,762
# マスター最大ボーカル 1,578
# マスター最大ビジュアル 2,078
#
# 1,250
# マスター最大ボーカル 2,668
# マスター最大ビジュアル 1,474
#
# 1,824
# マスター最大ボーカル 1,410
# マスター最大ビジュアル 2,152
#
# 2,286
# マスター最大ボーカル 2,238
# マスター最大ビジュアル 2,698
#
# 1,820
# マスター最大ボーカル 2,228
# マスター最大ビジュアル 2,148
#
# 1,878
# マスター最大ボーカル 2,704
# マスター最大ビジュアル 2,214
#
# 2,256
# マスター最大ボーカル 2,150
# マスター最大ビジュアル 2,664
#
# 1,476
# マスター最大ボーカル 2,088
# マスター最大ビジュアル 1,740
#
# 2,312
# マスター最大ボーカル 2,096
# マスター最大ビジュアル 2,728
#
# 1,780
# マスター最大ボーカル 2,764
# マスター最大ビジュアル 2,100
#
# 1,892
# マスター最大ボーカル 2,228
# マスター最大ビジュアル 2,232
#
# 1,746
# マスター最大ボーカル 2,054
# マスター最大ビジュアル 2,062
#
# 1,722
# マスター最大ボーカル 2,200
# マスター最大ビジュアル 2,030
#
# 1,870
# マスター最大ボーカル 1,552
# マスター最大ビジュアル 2,206
#
# 1,752
# マスター最大ボーカル 1,542
# マスター最大ビジュアル 2,068
#
# 1,874
# マスター最大ボーカル 2,202
# マスター最大ビジュアル 2,210
#
# 1,850
# マスター最大ボーカル 2,204
# マスター最大ビジュアル 2,182
#
# 2,278
# マスター最大ボーカル 2,044
# マスター最大ビジュアル 2,686
#
# 2,352
# マスター最大ボーカル 1,530
# マスター最大ビジュアル 2,776
#
# 1,856
# マスター最大ボーカル 1,920
# マスター最大ビジュアル 2,188
#
# 2,084
# マスター最大ボーカル 2,176
# マスター最大ビジュアル 2,460
#
# 2,018
# マスター最大ボーカル 1,800
# マスター最大ビジュアル 2,382
#
# 2,442
# マスター最大ボーカル 1,604
# マスター最大ビジュアル 2,882
#
# 1,856
# マスター最大ボーカル 2,842
# マスター最大ビジュアル 2,192
#
# 1,798
# マスター最大ボーカル 2,078
# マスター最大ビジュアル 2,122
#
# 1,864
# マスター最大ボーカル 1,448
# マスター最大ビジュアル 2,200
#
# 1,274
# マスター最大ボーカル 2,850
# マスター最大ビジュアル 1,502
#
# 2,396
# マスター最大ボーカル 1,574
# マスター最大ビジュアル 2,828
#
# 1,740
# マスター最大ボーカル 2,866
# マスター最大ビジュアル 2,052
#
# 1,742
# マスター最大ボーカル 2,784
# マスター最大ビジュアル 2,054
#
# 1,880
# マスター最大ボーカル 2,468
# マスター最大ビジュアル 2,220
#
# 2,322
# マスター最大ボーカル 2,238
# マスター最大ビジュアル 2,738
#
# 2,162
# マスター最大ボーカル 2,120
# マスター最大ビジュアル 2,550
#
# 1,834
# マスター最大ボーカル 2,238
# マスター最大ビジュアル 2,166
#
# 1,878
# マスター最大ボーカル 1,802
# マスター最大ビジュアル 2,218
#
# 1,824
# マスター最大ボーカル 2,780
# マスター最大ビジュアル 2,152
#
# 2020-06-07 01:11:10.109898
# 2020-06-07 01:11:53.138359
# papara

# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime

time1 = datetime.datetime.now()



connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'test' , charset = 'utf8') 
cursor = connection.cursor()
#cursor.execute('TRUNCATE TABLE `test`.`cards_n`')



def get_data(url , image):
    
    name = url[1:]
    
    req = requests.get(url)
    bs = BeautifulSoup(req.text , 'lxml')
    
    temp = bs.select('.ui_wikidb_top_area')
    content = temp[0].text
    
    content = content[content.find('キャラ') + 4 :]
    idol = content[:content.find('\n')]
    
    content = content[content.find('カード番号') + 6 :]
    number = int(content[:content.find('\n')])
    
    
    
    temp = bs.select('.ui_wikidb_middle_area')
    content = temp[0].text
    
    content = content[content.find('最大合計値') + 6:]
    total = content[: content.find('\n')]
    total = total.replace(',' , '')
    
    content = content[content.find('最大ダンス') + 6:]
    dance = content[:content.find('\n')]
    dance = dance.replace(',' , '')
    
    content = content[content.find('最大ボーカル') + 7:]
    vocal = content[:content.find('\n')]
    vocal = vocal.replace(',' , '')
    
    content = content[content.find('最大ビジュアル') + 8:]
    visual = content[:content.find('\n')]
    visual = visual.replace(',' , '')
    print(content)


    q = cursor.execute('''INSERT INTO `test`.`cards_others`(`id` , `name_jp` , `name_tw` , `idol` , 
    `total` , `dance` , `vocal` , `visual` , `date` , `image` , `ori_url`) 
    VALUES (%s , %s , %s , %s,
    # %s , %s , %s , %s , %s , %s , %s)''' , 
    (number , name , name , idol,
    total , dance , vocal , visual , '2017-06-29' , image , url))







def get_url(url):
    
    req = requests.get(url)
    bs = BeautifulSoup(req.text , 'lxml')
    homepage = 'https://imasml-theater-wiki.gamerch.com'
    
    
    temp = bs.select('.no-min-width')
    
    for i in temp:
        if i['data-col'] == '0':
            line = i.select('a')
            if len(line) != 0:
                line = line[0]
                img = line.select('img')[0]
                image = img['data-original']
                get_data(homepage + line['href'] , image)
    
    
    
    
                

homepage_N = 'https://imasml-theater-wiki.gamerch.com/N%EF%BC%8B'
get_url(homepage_N)

connection.commit()
cursor.close()
connection.close()
time2 = datetime.datetime.now()
print(time1)
print(time2)
print('papara')
# Out:
# 2,577
# マスター最大ボーカル 3,823
# マスター最大ビジュアル 2,885
#
# 1,795
# マスター最大ボーカル 4,037
# マスター最大ビジュアル 2,011
#
# 3,455
# マスター最大ボーカル 2,910
# マスター最大ビジュアル 3,871
#
# 2,739
# マスター最大ボーカル 2,941
# マスター最大ビジュアル 3,067
#
# 2,801
# マスター最大ボーカル 2,635
# マスター最大ビジュアル 3,137
#
# 2,727
# マスター最大ボーカル 2,288
# マスター最大ビジュアル 3,055
#
# 2,705
# マスター最大ボーカル 3,012
# マスター最大ビジュアル 3,029
#
# 2,764
# マスター最大ボーカル 3,941
# マスター最大ビジュアル 3,096
#
# 2,650
# マスター最大ボーカル 2,248
# マスター最大ビジュアル 2,970
#
# 2,680
# マスター最大ボーカル 3,782
# マスター最大ビジュアル 3,000
#
# 2,698
# マスター最大ボーカル 2,913
# マスター最大ビジュアル 3,022
#
# 2,575
# マスター最大ボーカル 3,059
# マスター最大ビジュアル 2,883
#
# 1,860
# マスター最大ボーカル 3,000
# マスター最大ビジュアル 2,084
#
# 2,728
# マスター最大ボーカル 3,056
# マスター最大ビジュアル 3,056
#
# 2,806
# マスター最大ボーカル 3,784
# マスター最大ビジュアル 3,142
#
# 3,243
# マスター最大ボーカル 2,728
# マスター最大ビジュアル 3,631
#
# 2,644
# マスター最大ボーカル 2,246
# マスター最大ビジュアル 2,960
#
# 1,876
# マスター最大ボーカル 3,798
# マスター最大ビジュアル 2,100
#
# 2,736
# マスター最大ボーカル 2,007
# マスター最大ビジュアル 3,064
#
# 3,430
# マスター最大ボーカル 3,186
# マスター最大ビジュアル 3,842
#
# 2,729
# マスター最大ボーカル 3,173
# マスター最大ビジュアル 3,057
#
# 2,214
# マスター最大ボーカル 2,972
# マスター最大ビジュアル 2,478
#
# 3,469
# マスター最大ボーカル 2,985
# マスター最大ビジュアル 3,885
#
# 2,618
# マスター最大ボーカル 2,926
# マスター最大ビジュアル 2,934
#
# 2,806
# マスター最大ボーカル 2,210
# マスター最大ビジュアル 3,142
#
# 2,812
# マスター最大ボーカル 3,134
# マスター最大ビジュアル 3,148
#
# 2,816
# マスター最大ボーカル 3,849
# マスター最大ビジュアル 3,152
#
# 3,384
# マスター最大ボーカル 3,062
# マスター最大ビジュアル 3,792
#
# 2,670
# マスター最大ボーカル 3,935
# マスター最大ビジュアル 2,990
#
# 2,628
# マスター最大ボーカル 2,195
# マスター最大ビジュアル 2,944
#
# 3,416
# マスター最大ボーカル 2,910
# マスター最大ビジュアル 3,824
#
# 2,775
# マスター最大ボーカル 3,138
# マスター最大ビジュアル 3,107
#
# 3,027
# マスター最大ボーカル 2,561
# マスター最大ビジュアル 3,391
#
# 3,528
# マスター最大ボーカル 2,180
# マスター最大ビジュアル 3,952
#
# 3,125
# マスター最大ボーカル 3,099
# マスター最大ビジュアル 3,501
#
# 2,784
# マスター最大ボーカル 4,047
# マスター最大ビジュアル 3,120
#
# 2,612
# マスター最大ボーカル 3,964
# マスター最大ビジュアル 2,924
#
# 3,482
# マスター最大ボーカル 3,187
# マスター最大ビジュアル 3,898
#
# 2,583
# マスター最大ボーカル 3,132
# マスター最大ビジュアル 2,891
#
# 2,696
# マスター最大ボーカル 2,959
# マスター最大ビジュアル 3,020
#
# 2,818
# マスター最大ボーカル 2,566
# マスター最大ビジュアル 3,158
#
# 3,244
# マスター最大ボーカル 3,019
# マスター最大ビジュアル 3,632
#
# 2,783
# マスター最大ボーカル 2,735
# マスター最大ビジュアル 3,115
#
# 2,796
# マスター最大ボーカル 2,061
# マスター最大ビジュアル 3,132
#
# 1,911
# マスター最大ボーカル 4,056
# マスター最大ビジュアル 2,139
#
# 2,611
# マスター最大ボーカル 4,082
# マスター最大ビジュアル 2,923
#
# 2,751
# マスター最大ボーカル 3,186
# マスター最大ビジュアル 3,083
#
# 2,821
# マスター最大ボーカル 3,513
# マスター最大ビジュアル 3,161
#
# 3,594
# マスター最大ボーカル 2,242
# マスター最大ビジュアル 4,026
#
# 3,663
# マスター最大ボーカル 2,285
# マスター最大ビジュアル 4,103
#
# 2,838
# マスター最大ボーカル 3,171
# マスター最大ビジュアル 3,178
#
# 2,735
# マスター最大ボーカル 3,959
# マスター最大ビジュアル 3,063
#
# 2020-06-07 01:11:59.400717
# 2020-06-07 01:12:44.026270
# papara
