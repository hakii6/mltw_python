# %%
import requests
import json
import csv
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime



# connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'mltd' , charset = 'utf8') 
# cursor = connection.cursor()

# cursor.execute('SELECT `id` , `name_jp` , `start_date` FROM `mltd`.`events`')
# q = cursor.fetchall()
# print(q)








for no in range(1 , 139):
    string = str(no)
    req = requests.get('https://api.matsurihi.me/mltd/v1/events/' + string)
    req.encoding = 'utf-8'
    content = req.text
    content = json.loads(content)

    try:
        a = content['type']
    except:
        print('err')
        continue
    
    
    if(content['type'] == 3 or content['type'] == 4):
        for i in q:
            if content['name'] == i[1]:
                print(i[1])
                
                print(i[0] , no)
                
                cursor.execute('UPDATE `mltd`.`events` SET `api_id` = %s WHERE `id` = %s' , (no , i[0]))
                break
                
        



# connection.commit()
# cursor.close()
# connection.close()
# Out:
# プラチナスターツアー～昏き星、遠い月～
# 246 20
# プラチナスターツアー～虹色letters～
# 242 23
# プラチナスターツアー～花ざかりWeekend✿～
# 229 32
# プラチナスターシアター～Eternal Harmony～
# 227 33
# プラチナスターツアー～咲くは浮世の君花火～
# 225 35
# err
# プラチナスターツアー～Blooming Star～
# 222 46
# プラチナスターシアター～サンリズム・オーケストラ♪～
# 220 48
# プラチナスターツアー～ビッグバンズバリボー!!!!!～
# 218 50
# プラチナスターシアター～Starry Melody～
# 212 56
# プラチナスターツアー～ラスト・アクトレス～
# 210 58
# プラチナスターシアター～ジャングル☆パーティー～
# 208 60
# プラチナスターシアター～PRETTY DREAMER～
# 204 64
# プラチナスターシアター～Raise the FLAG～
# 349 68
# プラチナスターツアー～だってあなたはプリンセス～
# 347 70
# プラチナスターツアー～月曜日のクリームソーダ～
# 343 74
# プラチナスターツアー～ラビットファー～
# 318 98
# プラチナスターツアー～Girl meets Wonder～
# 314 102
# プラチナスターシアター～G♡F～
# 312 104
# プラチナスターツアー～World Changer～
# 310 106
# プラチナスターシアター～待ちぼうけのLacrima～
# 308 108
# プラチナスターツアー～Cherry Colored Love～
# 306 110
# プラチナスターシアター～瞳の中のシリウス～
# 304 112
# プラチナスターツアー～Fermata in Rapsodia～
# 302 114
# プラチナスターシアター～俠気乱舞～
# 422 117
# プラチナスターツアー～百花は月下に散りぬるを～
# 420 119
# プラチナスターツアー～Super Duper～
# 416 123
# プラチナスターシアター～Beat the World!!!～
# 414 125
# ...
