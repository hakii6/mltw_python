# %%
import requests
import json
import csv
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime

connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'test' , charset = 'utf8') 
cursor = connection.cursor()
cursor.execute('SELECT `id` , `card_id` FROM `test`.`card_images` WHERE `image` like %s' , 
               ('https://cdn.img-conv.gamerch.com/' + '%',))

q = cursor.fetchall()
for i in q:
    print(i)



# def get_image(card_id):
    
#     req = requests.get('https://mltd.matsurihi.me/cards/931')
#     req.encoding='utf8'
#     bs = BeautifulSoup(req.text , 'lxml')

#     temp = bs.select('.card-img')

#     for i in temp:
#         line = i['style']
#         img = line[line.find('(\'') + 2 : line.find(')\'') - 1]
#         print(img)


# for i in range(1, 1000):
#     req = requests.get('https://api.matsurihi.me/mltd/v1/cards/' + str(i))
#     req.encoding='utf8'
#     temp = json.loads(req.text)
#     print(temp[0]['id'])
#     print(temp[0]['name'])


    
connection.commit()
cursor.close()
connection.close()
# Out:
# (103, 52)
# (104, 52)
# (105, 53)
# (106, 53)
# (107, 54)
# (108, 54)
# (109, 55)
# (110, 55)
# (111, 56)
# (112, 56)
# (113, 57)
# (114, 57)
# (115, 58)
# (116, 58)
# (117, 59)
# (118, 59)
# (119, 60)
# (120, 60)
# (121, 61)
# (122, 61)
# (123, 62)
# (124, 62)
# (125, 63)
# (126, 63)
# (127, 64)
# (128, 64)
# (129, 65)
# (130, 65)
# (131, 66)
# (132, 66)
# (133, 67)
# (134, 67)
# (135, 68)
# (136, 68)
# (137, 69)
# (138, 69)
# (139, 70)
# (140, 70)
# (141, 71)
# (142, 71)
# (143, 72)
# (144, 72)
# (145, 73)
# (146, 73)
# (147, 74)
# (148, 74)
# (149, 75)
# (150, 75)
# (151, 76)
# (152, 76)
# (153, 77)
# (154, 77)
# (155, 78)
# (156, 78)
# (157, 79)
# (158, 79)
# (159, 80)
# (160, 80)
# (161, 81)
# (162, 81)
# (163, 82)
# (164, 82)
# (165, 83)
# (166, 83)
# (167, 84)
# (168, 84)
# (169, 85)
# (170, 85)
# (171, 86)
# (172, 86)
# (173, 87)
# (174, 87)
# (175, 88)
# (176, 88)
# (177, 89)
# (178, 89)
# (179, 90)
# (180, 90)
# (181, 91)
# (182, 91)
# (183, 92)
# (184, 92)
# (185, 93)
# ...
