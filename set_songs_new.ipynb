# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime

time1 = datetime.datetime.now()



connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'test' , charset = 'utf8') 
cursor = connection.cursor()

cursor.execute('SELECT `id` , `name_jp` , `name_tw` FROM `test`.`events` WHERE type = %s OR type = %s' , ('tour' , 'theater'))
events = cursor.fetchall()

cursor.execute('SELECT `id` , `name_jp` , `name_tw` FROM `test`.`songs` WHERE get_song_type = %s' , ('App\Event' , ))
songs = cursor.fetchall()

for event in events:
    print(event)
    
    for song in songs:
        if(event[1].find(song[1]) != -1):
            print(song)
            cursor.execute('UPDATE `test`.`events` SET `name_tw` = REPLACE(`name_tw` , %s , %s) WHERE id = %s' , 
                           (song[1] , song[2] , event[0] ))
            cursor.execute('UPDATE `test`.`songs` SET `get_song_id` = %s WHERE id = %s' , 
                           (event[0] , song[0] ))    










connection.commit()
cursor.close()
connection.close()
time2 = datetime.datetime.now()
print(time1)
print(time2)
print('papara')
# Out:
# (102, 'プラチナスターツアー～Princess Be Ambitious！！～ ', '白金星光巡演～Princess Be Ambitious！！～ ')
# (104, 'プラチナスターシアター ～ドリームトラベラー～', '白金星光劇場 ～ドリームトラベラー～')
# (27, 'ドリームトラベラー', '夢想旅行者')
# (106, 'プラチナスターツアー ～Angelic Parade♪～ ', '白金星光巡演 ～Angelic Parade♪～ ')
# (26, 'Angelic Parade♪', 'Angelic Parade♪')
# (108, 'プラチナスターシアター ～STANDING ALIVE～', '白金星光劇場 ～STANDING ALIVE～')
# (24, 'STANDING ALIVE', 'STANDING ALIVE')
# (109, 'プラチナスターツアー ～FairyTaleじゃいられない～', '白金星光巡演 ～FairyTaleじゃいられない～')
# (18, 'FairyTaleじゃいられない', '不願再只是FairyTale')
# (111, 'プラチナスターシアター ～Growing Storm！～', '白金星光劇場 ～Growing Storm！～')
# (10, 'Growing Storm！', 'Growing Storm！')
# (113, 'プラチナスターシアター ～Good-Sleep，Baby♡～ ', '白金星光劇場 ～Good-Sleep，Baby♡～ ')
# (23, 'Good-Sleep，Baby♡', 'Good-Sleep，Baby♡')
# (116, 'プラチナスターシアター ～Shooting Stars～', '白金星光劇場 ～Shooting Stars～')
# (16, 'Shooting Stars', 'Shooting Stars')
# (202, 'プラチナスターツアー～ハルマチ女子～ ', '白金星光巡演～ハルマチ女子～ ')
# (72, 'ハルマチ女子', 'ハルマチ女子')
# (204, 'プラチナスターシアター～PRETTY DREAMER～', '白金星光劇場～PRETTY DREAMER～')
# (206, 'プラチナスターツアー～ハーモニクス～ ', '白金星光巡演～ハーモニクス～ ')
# (68, 'ハーモニクス', 'ハーモニクス')
# (208, 'プラチナスターシアター～ジャングル☆パーティー～', '白金星光劇場～ジャングル☆パーティー～')
# (210, 'プラチナスターツアー～ラスト・アクトレス～', '白金星光巡演～ラスト・アクトレス～')
# (64, 'ラスト・アクトレス', 'ラスト・アクトレス')
# (212, 'プラチナスターシアター～Starry Melody～', '白金星光劇場～Starry Melody～')
# (214, 'プラチナスターツアー～オーディナリィ・クローバー～ ', '白金星光巡演～オーディナリィ・クローバー～ ')
# (60, 'オーディナリィ・クローバー', 'オーディナリィ・クローバー')
# (216, 'プラチナスターシアター～brave HARMONY～ ', '白金星光劇場～brave HARMONY～ ')
