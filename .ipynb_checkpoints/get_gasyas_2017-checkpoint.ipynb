# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime



# connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'test' , charset = 'utf8') 
# cursor = connection.cursor()
# cursor.execute('TRUNCATE TABLE `test`.`gasyas_2017`')










def get_data(url):
    
    req = requests.get(url)
    bs = BeautifulSoup(req.text , 'lxml')
    
    temp = bs.select('.ui_anchor_container')
    
    
    
    for i in temp:
        if len(i.select('a')) != 0:
            temp = i.select('a')[0]
            if len(temp.text) != 0:
                line = temp.text
                start_date = line[:line.find('～')]
                line = line[line.find('～') + 1:]
                end_date = line[:10]
                print()
                
                a = i.select('a')[0]
                
                ori_url = urllib.parse.unquote(a['href'])
    
    
    
    
    
    
    
    img = bs.select('.t-line-img')
    for i in img:
        line = i.select('td')[0]
        if (line['rowspan'] == '7'):
            tag = line.select('img')[0]
#             print(tag['data-original'])
        
        
        
    


homepage_2017 = 'https://imasml-theater-wiki.gamerch.com/%E9%81%8E%E5%8E%BB%E3%81%AE%E3%82%AC%E3%82%B7%E3%83%A3%EF%BC%882017.06.29%EF%BD%9E2017.12.30%EF%BC%89'

get_data(homepage_2017)




# connection.commit()
# cursor.close()
# connection.close()
print('papara')
# Out:
# 2018.01.15
# https://imasml-theater-wiki.gamerch.com/新年！初詣ライブガシャ
# 2018.12.31
# https://imasml-theater-wiki.gamerch.com/ミリオンフェス（2017.12.27）
# 2017.12.27
# https://imasml-theater-wiki.gamerch.com/Princessタイプ限定ガシャ（2017.12.24）
# 2017.12.27
# https://imasml-theater-wiki.gamerch.com/ドリーミープラネッツガシャ
# 2017.12.21
# https://imasml-theater-wiki.gamerch.com/南の島でキャンプガシャ
# 2017.12.13
# https://imasml-theater-wiki.gamerch.com/みんなで楽しいクリスマスパーティー♪ガシャ
# 2017.11.27
# https://imasml-theater-wiki.gamerch.com/Angelタイプ限定ガシャ（2017.11.24）
# 2017.11.30
# https://imasml-theater-wiki.gamerch.com/魅惑のレースクイーンガシャ
# 2017.11.21
# https://imasml-theater-wiki.gamerch.com/アイドルの日常ガシャ VOL.3
# 2017.11.13
# https://imasml-theater-wiki.gamerch.com/秋色に染めて♪エンジョイオータムライブガシャ
# 2017.10.27
# https://imasml-theater-wiki.gamerch.com/Fairyタイプ限定ガシャ（2017.10.24）
# 2017.10.31
# https://imasml-theater-wiki.gamerch.com/Let’s プロモーション！CM撮影ガシャ
# 2017.10.20
# https://imasml-theater-wiki.gamerch.com/メルヘンドリームワールドガシャ
# 2017.10.11
# https://imasml-theater-wiki.gamerch.com/トリックオアトリート！ハロウィンタウンガシャ
# 2017.09.30
# https://imasml-theater-wiki.gamerch.com/元気に行進！アイドルマーチングフェスティバルガシャ
# 2017.09.20
# https://imasml-theater-wiki.gamerch.com/マジカルガールガシャ
# 2017.09.12
# https://imasml-theater-wiki.gamerch.com/アクアリウムライブガシャ
# 2017.08.31
# https://imasml-theater-wiki.gamerch.com/スプラッシュサマーガシャ
# 2017.08.22
# https://imasml-theater-wiki.gamerch.com/アイドルの日常ガシャ VOL.2
# 2017.08.09
# https://imasml-theater-wiki.gamerch.com/水着でリフレッシュ♪リゾートライブガシャ
# 2017.07.31
# https://imasml-theater-wiki.gamerch.com/アイドルの日常ガシャ VOL.1
# 2017.07.24
# https://imasml-theater-wiki.gamerch.com/夏だ！海だ！真夏の海水浴ガシャ
# 2017.07.13
# https://imasml-theater-wiki.gamerch.com/ようこそ！プロデューサーさんガシャ
# イベント
# https://imasml-theater-wiki.gamerch.com/イベント一覧
# ガシャ
# https://imasml-theater-wiki.gamerch.com/過去のガシャ
# キャンペーン
# https://imasml-theater-wiki.gamerch.com/過去のキャンペーン
# papara
