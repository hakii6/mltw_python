# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime

start_time = datetime.datetime.now()



connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'mltd' , charset = 'utf8') 
cursor = connection.cursor()
cursor.execute('TRUNCATE TABLE `mltd`.`events`')


def get_data(url , date , image):

    req = requests.get(url)
    bs = BeautifulSoup(req.text , 'lxml')
    
    title = bs.select('title')[0].text
    start_date = date[ : 10]
    while(start_date.find('(') != -1):
        start_date=start_date[:-1]
    end_date = date[date.find('～') + 2 : -3]    
    
    pos = title.rfind('～')
    name = title[:pos + 1]        
    
    if title.find('MILLION LIVE WORKING') != -1:
        start_date = date[ : 10]
        end_date = date[date.find('～') + 2 : -3]

        
        
        q = cursor.execute('INSERT INTO `mltd`.`events` (`name` , `start_date` , `end_date` , `image`) VALUES (%s , %s , %s , %s)' ,
            (name  , start_date , end_date , image))        
        
        
    elif title.find('ーツアー') != -1:


        
        string = str(bs)
        pos_A = string.find('イベント限定カード')
        pos_B = string.find('開催日時')
        part = string[pos_A : pos_B]

        bs = BeautifulSoup(part , 'lxml')
        part = bs.select('a')
        
        flag = 0
        
        
        
        
        cards = ''
        
        for i in part:
            if(i['title'] == "SR") or (i['title'] == "R"):
                continue
            if flag == 0:
                flag = 1
                continue
            cards = cards + i['title'] + '\n' #1 2 SR 3 R
            
        q = cursor.execute('INSERT INTO `mltd`.`events` (`name` , `cards` , `start_date` , `end_date` , `image`) VALUES (%s , %s, %s , %s , %s)' ,
            (name , cards[:-1] , start_date , end_date , image))
    
            
            
    elif title.find('ーシアター') != -1:


                
        string = str(bs)
        pos_A = string.find('イベント限定カード')
        pos_B = string.find('開催日時')
        part = string[pos_A : pos_B]

        bs = BeautifulSoup(part , 'lxml')
        part = bs.select('a')
        
        flag = 0;
        
        
        
        
        cards = ''
        for i in part:
            if(i['title'] == "SR") or (i['title'] == "R"):
                continue
            if flag == 0:
                flag = 1
                continue
            cards = cards + i['title'] + '\n' #1 2 SR 3 R        
    
    
        q = cursor.execute('INSERT INTO `mltd`.`events` (`name`, `cards` , `start_date` , `end_date` , `image`) VALUES (%s  , %s , %s , %s ,%s)' ,
            (name , cards[:-1] , start_date , end_date , image))    
    
    
    
    
    elif title.find('COLLECTION') != -1:
                           
                
        
        string = str(bs)
        pos_A = string.find('イベント限定カード')
        pos_B = string.find('開催日時')
        part = string[pos_A : pos_B]

        bs = BeautifulSoup(part , 'lxml')
        part = bs.select('a')
        
        flag = 0;                
        
        
        
        
        
        cards = ''
        for i in part:
            if(i['title'] == "SR") or (i['title'] == "R"):
                continue

            cards = cards + i['title']  + '\n' #1 2 SR 3 R

        q = cursor.execute('INSERT INTO `mltd`.`events` (`name` , `cards` , `start_date` , `end_date` , `image`) VALUES ( %s , %s , %s , %s , %s)' ,
            (name , cards[:-1] , start_date , end_date , image))
            
            
    else:
        
        q = cursor.execute('INSERT INTO `mltd`.`events` (`name` , `start_date` , `end_date` , `image`) VALUES (%s , %s , %s , %s)' ,
            (name , start_date , end_date , image))        
        
    print(name)
        
        
def get_url(hp):
    
    req = requests.get(hp)
    bs = BeautifulSoup(req.text , 'lxml')

    temp = bs.select('.t-line-img')[0]
    td = temp.select('.no-min-width')
    
    
    
    image_list = []
    tag = bs.select('img')
    for line in tag:
        string = str(line)
        if(string.find('width="350"') != -1):
            image_list.append(line['data-original'])
    
    
    
    flag = 1
    flag2 = 1
    count = 0
    url_list = []
    date_list = []
    for i in td:
        
        if(i['data-col'] == '0'):
            if (flag):
                flag = 0
                continue 
            temp = i.select('a')[0]['href']
            if temp not in url_list:
                url_list.append(temp)
                count = count + 1        
        
        elif(i['data-col'] == '1' and i['style'] == 'text-align:center;background:#white !important;'):
            if(i.text.find('2020') != -1 or i.text.find('2019') != -1 or i.text.find('2018') != -1 or i.text.find('2017') != -1):
                date_list.append(i.text)

    for url in url_list:
        get_data(url , date_list[0] , image_list[0])
        date_list.pop(0)
        image_list.pop(0)
        

        
        
        
        
        
homepage_2020 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7'
homepage_2019 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7%EF%BC%882019.01.01%EF%BD%9E2019.12.31%EF%BC%89'
homepage_2018 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7%EF%BC%882018.01.01%EF%BD%9E2018.12.31%EF%BC%89'
homepage_2017 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7%EF%BC%882017.07.14%EF%BD%9E2017.12.31%EF%BC%89'
get_url(homepage_2020)
get_url(homepage_2019)
get_url(homepage_2018)
get_url(homepage_2017)

print('')
print(start_time)
print(datetime.datetime.now())

connection.commit()
cursor.close()
connection.close()
print('papara')
# Out:
# 【イベント】プラチナスターシアター～アライブファクター～
# 【ミリシタ】MILLION LIVE WORKING☆～大ヒット！アイドル商品開発部～
# 【ミリシタ】プラチナスターツアー～絶対的Performer～
# 【イベント】ミリコレ！～MILLIONLIVE COLLECTION～
# 【イベント】プラチナスターシアター～Bigバルーン◎～
# 【ミリシタ】MILLION LIVE WORKING☆～大合奏！アイドルシンフォニー～
# 【ミリシタ】プラチナスターツアー～クルリウタ～
# 【イベント】ミリコレ！～MILLIONLIVE COLLECTION～
# 【ミリシタ】プラチナスターシアター～Helloコンチェルト～
# 【ミリシタ】超ビーチバレー ～超全国大会編～
# 【イベント】MILLION LIVE WORKING☆～もっと！輝け！アイドル強化合宿～
# 【ミリシタ】プラチナスターツインステージ～深淵の蒼、熱焔の緋～
# 【イベント】ミリコレ！～MILLIONLIVE COLLECTION～
# 【ミリシタ】プラチナスターシアター～Beat the World!!!～
# 【ミリシタ】MILLION LIVE WORKING☆～期間限定★アイドルカフェ～
# 【ミリシタ】プラチナスターツアー～Super Duper～
# 【イベント】ミリコレ！～MILLIONLIVE COLLECTION～
# 【イベント】プラチナスターシアター ～ドリームトラベラー～
#
# 【イベント】プラチナスターツアー ～Angelic Parade♪～
# 【イベント】ミリコレ！～MILLIONLIVE COLLECTION～
# 【イベント】プラチナスターシアター ～STANDING ALIVE～
# 【イベント】プラチナスターツアー ～FairyTaleじゃいられない～
# 【イベント】ミリコレ！～MILLIONLIVE COLLECTION～
# 【イベント】プラチナスターシアター ～Growing Storm！～
# 【イベント】ミリコレ！～MILLIONLIVE COLLECTION～
# 【イベント】プラチナスターシアター ～Good-Sleep，Baby♡～
#
# 【イベント】ミリコレ！～MILLIONLIVE COLLECTION～
# 【イベント】プラチナスターシアター ～Shooting Stars～
#
# 【イベント】ミリコレ！～MILLIONLIVE COLLECTION～
#
#
# 2020-06-04 20:22:41.881864
# 2020-06-04 20:24:53.646427
# papara

# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime

start_time = datetime.datetime.now()






def get_url(hp):
    
    req = requests.get(hp)
    bs = BeautifulSoup(req.text , 'lxml')

    temp = bs.select('.t-line-img')[0]
    td = temp.select('.no-min-width')
    

    tag = bs.select('img')
    for line in tag:
        string = str(line)
        if(string.find('width="350"') != -1):
            print(line['data-original'])
    
    
    
    
    flag = 1
    flag2 = 1
    count = 0
    url_list = []
    date_list = []
    for i in td:
        
        if(i['data-col'] == '0'):
            if (flag):
                flag = 0
                continue 
            temp = i.select('a')[0]['href']
            if temp not in url_list:
                url_list.append(temp)
                count = count + 1        
        
        elif(i['data-col'] == '1' and i['style'] == 'text-align:center;background:#white !important;'):
            if(i.text.find('2020') != -1 or i.text.find('2019') != -1 or i.text.find('2018') != -1 or i.text.find('2017') != -1):
                date_list.append(i.text)

    for url in url_list:
        #get_data(url , date_list[0])
        date_list.pop(0)

        
        
        
        

homepage_2020 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7'
homepage_2019 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7%EF%BC%882019.01.01%EF%BD%9E2019.12.31%EF%BC%89'
homepage_2018 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7%EF%BC%882018.01.01%EF%BD%9E2018.12.31%EF%BC%89'
homepage_2017 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7%EF%BC%882017.07.14%EF%BD%9E2017.12.31%EF%BC%89'
get_url(homepage_2020)
# get_url(homepage_2019)
# get_url(homepage_2018)
# get_url(homepage_2017)

print('')
print(start_time)
print(datetime.datetime.now())
# Out:
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1590559802.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1589782278.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1589178709.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1588400052.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1588054762.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1587277354.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1586588775.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1585807663.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1585667369.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1585289350.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1584517952001.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1583907024.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1583129394.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1582783674.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1582006354.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1581401534.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1580626383.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1580279254.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1579504007.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1578809391.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1577944874.jpg
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1577344916.jpg
#
# 2020-05-30 12:05:30.605830
# 2020-05-30 12:05:31.219865

# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime

start_time = datetime.datetime.now()



connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'mltd' , charset = 'utf8') 
cursor = connection.cursor()
cursor.execute('TRUNCATE TABLE `test`.`events`')


def get_data(url , date , image):

    req = requests.get(url)
    bs = BeautifulSoup(req.text , 'lxml')
    
    title = bs.select('title')[0].text
    start_date = date[ : 10]
    while(start_date.find('(') != -1):
        start_date=start_date[:-1]
    end_date = date[date.find('～') + 2 : -3]    
    
    pos = title.rfind('～')
    name = title[:pos + 1]        
    
    if title.find('MILLION LIVE WORKING') != -1:
        start_date = date[ : 10]
        end_date = date[date.find('～') + 2 : -3]

        
        
        q = cursor.execute('INSERT INTO `mltd`.`events` (`name` , `start_date` , `end_date` , `image`) VALUES (%s , %s , %s , %s)' ,
            (name  , start_date , end_date , image))        
        
        
    elif title.find('ーツアー') != -1:


        
        string = str(bs)
        pos_A = string.find('イベント限定カード')
        pos_B = string.find('開催日時')
        part = string[pos_A : pos_B]

        bs = BeautifulSoup(part , 'lxml')
        part = bs.select('a')
        
        flag = 0
        
        
        
        
        cards = ''
        
        for i in part:
            if(i['title'] == "SR") or (i['title'] == "R"):
                continue
            if flag == 0:
                flag = 1
                continue
            cards = cards + i['title'] + '\n' #1 2 SR 3 R
            
        q = cursor.execute('INSERT INTO `mltd`.`events` (`name` , `cards` , `start_date` , `end_date` , `image`) VALUES (%s , %s, %s , %s , %s)' ,
            (name , cards[:-1] , start_date , end_date , image))
    
            
            
    elif title.find('ーシアター') != -1:


                
        string = str(bs)
        pos_A = string.find('イベント限定カード')
        pos_B = string.find('開催日時')
        part = string[pos_A : pos_B]

        bs = BeautifulSoup(part , 'lxml')
        part = bs.select('a')
        
        flag = 0;
        
        
        
        
        cards = ''
        for i in part:
            if(i['title'] == "SR") or (i['title'] == "R"):
                continue
            if flag == 0:
                flag = 1
                continue
            cards = cards + i['title'] + '\n' #1 2 SR 3 R        
    
    
        q = cursor.execute('INSERT INTO `mltd`.`events` (`name`, `cards` , `start_date` , `end_date` , `image`) VALUES (%s  , %s , %s , %s ,%s)' ,
            (name , cards[:-1] , start_date , end_date , image))    
    
    
    
    
    elif title.find('COLLECTION') != -1:
                           
                
        
        string = str(bs)
        pos_A = string.find('イベント限定カード')
        pos_B = string.find('開催日時')
        part = string[pos_A : pos_B]

        bs = BeautifulSoup(part , 'lxml')
        part = bs.select('a')
        
        flag = 0;                
        
        
        
        
        
        cards = ''
        for i in part:
            if(i['title'] == "SR") or (i['title'] == "R"):
                continue

            cards = cards + i['title']  + '\n' #1 2 SR 3 R

        q = cursor.execute('INSERT INTO `mltd`.`events` (`name` , `cards` , `start_date` , `end_date` , `image`) VALUES ( %s , %s , %s , %s , %s)' ,
            (name , cards[:-1] , start_date , end_date , image))
            
            
    else:
        
        q = cursor.execute('INSERT INTO `mltd`.`events` (`name` , `start_date` , `end_date` , `image`) VALUES (%s , %s , %s , %s)' ,
            (name , start_date , end_date , image))        
        
    print(name)
        
        
def get_url(hp):
    
    req = requests.get(hp)
    bs = BeautifulSoup(req.text , 'lxml')

    temp = bs.select('.t-line-img')[0]
    td = temp.select('.no-min-width')
    
    
    
    image_list = []
    tag = bs.select('img')
    for line in tag:
        string = str(line)
        if(string.find('width="350"') != -1):
            image_list.append(line['data-original'])
    
    
    
    flag = 1
    flag2 = 1
    count = 0
    url_list = []
    date_list = []
    for i in td:
        
        if(i['data-col'] == '0'):
            if (flag):
                flag = 0
                continue 
            temp = i.select('a')[0]['href']
            if temp not in url_list:
                url_list.append(temp)
                count = count + 1        
        
        elif(i['data-col'] == '1' and i['style'] == 'text-align:center;background:#white !important;'):
            if(i.text.find('2020') != -1 or i.text.find('2019') != -1 or i.text.find('2018') != -1 or i.text.find('2017') != -1):
                date_list.append(i.text)

    for url in url_list:
        get_data(url , date_list[0] , image_list[0])
        date_list.pop(0)
        image_list.pop(0)
        

        
        
        
        
        
homepage_2020 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7'
get_url(homepage_2020)


print('')
print(start_time)
print(datetime.datetime.now())

connection.commit()
cursor.close()
connection.close()
print('papara')
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-1-4ceaa01458a7> in <module>
#     196 homepage_2018 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7%EF%BC%882018.01.01%EF%BD%9E2018.12.31%EF%BC%89'
#     197 homepage_2017 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7%EF%BC%882017.07.14%EF%BD%9E2017.12.31%EF%BC%89'
# --> 198 get_url(homepage_2020)
#     199 get_url(homepage_2019)
#     200 get_url(homepage_2018)
#
# <ipython-input-1-4ceaa01458a7> in get_url(hp)
#     182
#     183     for url in url_list:
# --> 184         get_data(url , date_list[0] , image_list[0])
#     185         date_list.pop(0)
#     186         image_list.pop(0)
#
# <ipython-input-1-4ceaa01458a7> in get_data(url, date, image)
#     100
#     101         q = cursor.execute('INSERT INTO `mltd`.`events` (`name`, `cards` , `start_date` , `end_date` , `image`) VALUES (%s  , %s , %s , %s ,%s)' ,
# --> 102             (name , cards[:-1] , start_date , end_date , image))
#     103
#     104
#
# ~\anaconda3\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     207
#     208         assert isinstance(query, (bytes, bytearray))
# --> 209         res = self._query(query)
#     210         return res
#     211
#
# ~\anaconda3\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     313         db = self._get_db()
#     314         self._result = None
# --> 315         db.query(q)
#     316         self._do_get_result(db)
#     317         self._post_get_result()
#
# ~\anaconda3\lib\site-packages\MySQLdb\connections.py in query(self, query)
#     237         if isinstance(query, bytearray):
#     238             query = bytes(query)
# --> 239         _mysql.connection.query(self, query)
#     240
#     241     def _bytes_literal(self, bs):
#
# IntegrityError: (1364, "Field 'name_tw' doesn't have a default value")

# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime

start_time = datetime.datetime.now()



# connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'mltd' , charset = 'utf8') 
# cursor = connection.cursor()
# cursor.execute('TRUNCATE TABLE `test`.`events`')


def get_date(url):
    req = requests.get(url)
    bs = BeautifulSoup(req.text , 'lxml')
    
    string = str(bs)
    string = string[string.find('開催期間'):string.find('概要')]
    
    bs = BeautifulSoup(string , 'lxml')
    print('papara')
    
    string = bs.text
    string = string[string.find('20'):]
    
    return bs.text
    
    
    

        
        
def get_url(hp):
    
    req = requests.get(hp)
    bs = BeautifulSoup(req.text , 'lxml')

    table = bs.select('tbody')[0]
    data = table.select('td')
    for i in data:
        if(i['data-col'] == '0' ):
            img = i.select('img')
            if(len(img) == 0):
                temp = i.select('a')[0]
                ori_url = temp['href']
#                 print(ori_url)
                name_jp = temp.text
#                 print(name_jp)
            else:
#                 print(img[0]['data-original'])
                image = img[0]['data-original']
                print(get_date(ori_url))
    
        
    
    

        
        
        
        
        
homepage_2019 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7%EF%BC%882019.01.01%EF%BD%9E2019.12.31%EF%BC%89'
get_url(homepage_2019)



print('')
print(start_time)
print(datetime.datetime.now())

# connection.commit()
# cursor.close()
# connection.close()
print('papara')
# Out:
# papara
# 開催期間＞
# 2019/12/26(木)15:00 ～2020/01/01(水) 23:59
#
#
#
#
# papara
# 開催期間＞
# 2019/12/17(火) 15:00 ～ 2019/12/24(火) 20:59
# ＜イベント楽曲＞
# Fermata in Rapsodia
#
#
#
# イベント
# papara
#
# papara
# 開催期間＞
# 2019/12/01(日)15:00 ～ 2019/12/08(日) 20:59
# ＜イベント楽曲＞
# 瞳の中のシリウス
#
#
#
# イベント
# papara
# 開催期間＞
# 2019/11/27(水)15:00 ～ 2019/11/30(土) 23:59
#
#
#
#
# papara
# 開催期間＞
# 2019/11/18(月) 15:00 ～ 2019/11/25(月) 20:59
# ＜イベント楽曲＞
# Cherry Colored Love
#
#
#
# 本イベントの変更点
# イベント
# papara
#
# papara
# 開催期間＞
# 2019/11/02(土)15:00 ～ 2019/11/08(金) 20:59
# ＜イベント楽曲＞
# 待ちぼうけのLacrima
#
#
#
# イベント
# papara
# 開催期間＞
# 2019/10/29(火)15:00 ～ 2019/11/01(金) 23:59
#
#
#
#
# papara
# 開催期間＞
# 2019/10/20(日) 15:00 ～ 2019/10/27(日) 20:59
# ＜イベント楽曲＞
# World Changer
#
#
#
# 本イベントの変更点
# イベント
# papara
#
# papara
# 開催期間＞
# 2019/10/03(木)15:00 ～ 2019/10/10(木) 20:59
# ＜イベント楽曲＞
# G♡F
#
#
#
# 本イベントの変更点
# イベント
# papara
# 開催期間＞
# 2019/09/28(土) 15:00 ～ 2019/10/02(水) 23:59
#
#
#
# 本イベントの変更点
#
# papara
# 開催期間＞
# 2019/09/19(木) 15:00 ～ 2019/09/26(木) 20:59
# ＜イベント楽曲＞
# Girl meets Wonder
#
#
#
# 本イベントの変更点
# イベント
# papara
#
# papara
# 開催期間＞
# 2019/09/03(火)15:00 ～ 2019/09/10(火) 20:59
# ＜イベント楽曲＞
# 赤い世界が消える頃
#
#
#
# イベント
# papara
# 開催期間＞
# 2019/08/30(金)15:00 ～ 2019/09/02(月) 23:59
#
#
#
#
# papara
# 開催期間＞
# 2019/08/21(水) 15:00 ～ 2019/08/28(水) 20:59
# ＜イベント楽曲＞
# ラビットファー
#
#
#
# イベント
# papara
#
# papara
# 開催期間＞
# 2019/08/04(日)15:00 ～ 2019/08/12(月) 20:59
# ＜イベント楽曲＞
# ランニング・ハイッ
#
#
#
# イベント
# papara
# 開催期間＞
# 2019/07/31(水)15:00 ～ 2019/08/03(土) 23:59
#
#
#
#
# papara
# 開催期間＞
# 2019/07/23(火) 15:00 ～ 2019/07/29(月) 20:59
# ＜イベント楽曲＞
# dans l’obscurité
#
#
#
# イベント
# papara
#
# papara
# 開催期間＞
# 2019/07/01(月)00:00 ～ 2019/07/13(土) 23:59
# ＜イベント楽曲＞
# Flyers！！！
#
#
#
# イベント
# papara
# 開催期間＞
# 2019/06/27(木) 15:00 ～ 2019/06/30(日) 23:59
#
#
#
#
# papara
# 開催期間＞
# 2019/06/19(水) 15:00 ～ 2019/06/26(水) 20:59
# ＜イベント楽曲＞
# White Vows
#
#
#
# イベント
# papara
#
# papara
# 開催期間＞
# 2019/06/03(月)15:00 ～ 2019/06/10(月) 20:59
# ＜イベント楽曲＞
# fruity love
#
#
#
# イベント
# papara
# 開催期間＞
# 2019/05/30(木)15:00 ～ 2019/06/02(日) 23:59
#
#
#
#
# papara
# 開催期間＞
# 2019/05/20(月) 15:00 ～ 2019/05/28(火) 20:59
# ＜イベント楽曲＞
# LEADER‼
#
#
#
# イベント
# papara
#
# papara
# 開催期間＞
# 2019/05/02(木)15:00 ～ 2019/05/10(金) 20:59
# ＜イベント楽曲＞
# プリムラ
#
#
#
# イベント
# papara
# 開催期間＞
# 2019/04/28(日)15:00 ～ 2019/05/01(水) 23:59
#
#
#
#
# papara
# 開催期間＞
# 2019/04/19(金) 15:00 ～ 2019/04/26(金) 20:59
# ＜イベント楽曲＞
# Episode．Tiara
#
#
#
# イベント
# papara
#
# papara
# 開催期間＞
# 2019/04/02(火) 15:00 ～ 2019/04/10(水) 20:59
# ＜イベント楽曲＞
# Justice OR Voice
#
#
#
# イベント
# papara
# 開催期間＞
# 2019/04/01(月) 00:00 ～2018/04/01(月) 23:59
#
#
#
# papara
# 開催期間＞
# 2019/03/27(水) 15:00 ～ 03/31(日) 23:59
#
#
#
# イベント
# papara
# 開催期間＞
# 2019/03/19(火) 15:00 ～ 2019/03/25(月) 20:59
# ＜イベント楽曲＞
# ピコピコIIKO！ インベーダー
#
#
#
# イベント
# papara
#
# papara
# 開催期間＞
# 2019/03/04(月)15:00 ～ 2019/03/10(日) 20:59
# ＜イベント楽曲＞
# Bonnes! Bonnes!! Vacances!!!
#
#
#
# イベント
# papara
# 開催期間＞
# 2019/02/28(木)15:00 ～ 2019/03/03(日) 23:59
#
#
#
#
# papara
# 開催期間＞
# 2019/02/19(火) 15:00 ～ 2019/02/26(火) 20:59
# ＜イベント楽曲＞
# 月曜日のクリームソーダ
#
#
#
# イベント
# papara
#
# papara
# 開催期間＞
# 2019/02/02(土)15:00 ～ 2019/02/10(日) 20:59
# ＜イベント楽曲＞
# 成長Chu→LOVER‼
#
#
#
# イベント
# papara
# 開催期間＞
# 2019/01/29(火)15:00 ～ 2019/02/1(金) 23:59
#
#
#
#
# papara
# 開催期間＞
# 2019/01/20(日) 15:00 ～ 2019/01/27(日) 20:59
# ＜イベント楽曲＞
# だってあなたはプリンセス
#
#
#
# イベント
# papara
#
# papara
# 開催期間＞
# 2019/01/04(金)15:00 ～ 2018/01/11(金) 20:59
# ＜イベント楽曲＞
# Raise the FLAG
#
#
#
# イベント
# papara
# 開催期間＞
# 2018/12/30(日)15:00 ～ 2019/1/3(木) 23:59
#
#
#
#
#
# 2020-06-06 15:13:55.391849
# 2020-06-06 15:14:37.907281
# papara
