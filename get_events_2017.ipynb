# %%
import MySQLdb
import cv2
import requests
import urllib.parse
from urllib.parse import unquote

from bs4 import BeautifulSoup
from urllib.parse import urljoin
import datetime

start_time = datetime.datetime.now()



connection = MySQLdb.connect(host = "127.0.0.1" , user = "root" , password = "zxcv2587", db = 'mltd' , charset = 'utf8') 
cursor = connection.cursor()
cursor.execute('TRUNCATE TABLE `test`.`events_2017`')



    

        
        
def get_url(hp):
    
    req = requests.get(hp)
    bs = BeautifulSoup(req.text , 'lxml')

    table = bs.select('tbody')[0]
    data = table.select('td')
    flag = 0
    count = 100
    for i in data:
        if(i['data-col'] == '1' and flag == 1):
            date = i.text
            start_date = date[:date.find(')')-2]
            date = date[date.find(')'):]
            end_date = date[date.find('20'):date.rfind(')')-2]
            if(len(end_date) == 0):
                end_date = start_date

            
        if(i['data-col'] == '0' ):
            img = i.select('img')
            if(len(img) == 0):
                flag = 1
                temp = i.select('a')[0]
                ori_url = temp['href'] #url
                
                ori_url = urllib.parse.unquote(ori_url)    #utf-8
                name_jp = temp.text #name
            else:
                count = count + 1
                flag = 0
                image = img[0]['data-original'] #image
                
                print(name_jp)
                print(start_date)
                print(end_date)                
                print(image)
                print(ori_url)
                
                
                
                q = cursor.execute('INSERT into `test`.`events_2017`(`id` , `name_jp` , `name_tw` , `start_date` , `end_date` , `image` , `ori_url`) VALUES(%s , %s, %s , %s , %s , %s , %s)' ,
                    (count , name_jp , name_jp , start_date , end_date , image , ori_url))
    
    
        
    
    

        
        
        
        
        
homepage_2017 = 'https://imasml-theater-wiki.gamerch.com/%E3%82%A4%E3%83%99%E3%83%B3%E3%83%88%E4%B8%80%E8%A6%A7%EF%BC%882017.07.14%EF%BD%9E2017.12.31%EF%BC%89'
get_url(homepage_2017)



print('')
print(start_time)
print(datetime.datetime.now())

connection.commit()
cursor.close()
connection.close()
print('papara')
# Out:
# THEATER SHOW TIME☆
# 2017/12/31
# 2018/01/02
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1504163979001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】THEATER SHOW TIME☆ 201712
# プラチナスターツアー～Princess Be Ambitious！！～
# 2017/12/21
# 2017/12/29
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1514435746001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターツアー～Princess Be Ambitious！！～
# ミリコレ！～MILLIONLIVE COLLECTION～
# 2017/12/13
# 2018/12/19
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1513150084001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】ミリコレ！～MILLIONLIVE COLLECTION～ 201712
# プラチナスターシアター ～ドリームトラベラー～
# 2017/12/4
# 2017/12/11
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1512368831001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターシアター ～ドリームトラベラー～
# THEATER SHOW TIME☆
# 2018/11/30
# 2018/12/02
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1504163979001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】THEATER SHOW TIME☆ 201711
# プラチナスターツアー ～Angelic Parade♪～
# 2017/11/21
# 2017/11/28
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1512368982001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターツアー ～Angelic Parade♪～
# ミリコレ！～MILLIONLIVE COLLECTION～
# 2017/11/11
# 2017/11/19
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1510381738.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】ミリコレ！～MILLIONLIVE COLLECTION～ 201711
# プラチナスターシアター ～STANDING ALIVE～
# 2017/11/01
# 2017/11/09
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1509519952001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターシアター ～STANDING ALIVE～
# プラチナスターツアー ～FairyTaleじゃいられない～
# 2017/10/20
# 2017/10/30
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1508482314001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターツアー ～FairyTaleじゃいられない～
# ミリコレ！～MILLIONLIVE COLLECTION～
# 2017/10/13
# 2018/10/18
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1507876146001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】ミリコレ！～MILLIONLIVE COLLECTION～ 201710
# プラチナスターシアター ～Growing Storm！～
# 2017/9/30
# 2017/10/10
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1506798678.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターシアター ～Growing Storm！～
# ミリコレ！～MILLIONLIVE COLLECTION～
# 2017/09/21
# 2018/09/28
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1505974807.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】ミリコレ！～MILLIONLIVE COLLECTION～ 201709
# プラチナスターシアター ～Good-Sleep，Baby♡～
# 2017/09/08
# 2017/09/19
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1504852608001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターシアター ～Good-Sleep，Baby♡～
# THEATER SHOW TIME☆
# 2017/08/31
# 2017/09/05
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1504163979001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】THEATER SHOW TIME☆ 201708
# ミリコレ！～MILLIONLIVE COLLECTION～
# 2017/08/23
# 2017/08/30
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1503469722001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】ミリコレ！～MILLIONLIVE COLLECTION～ 201708
# プラチナスターシアター ～Shooting Stars～
# 2017/08/12
# 2017/08/21
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1502521149.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】プラチナスターシアター ～Shooting Stars～
# THEATER SHOW TIME☆
# 2017/07/31
# 2018/08/07
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1500009382001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】THEATER SHOW TIME☆ 201707
# ミリコレ！～MILLIONLIVE COLLECTION～
# 2018/07/21
# 2018/07/28
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1500607806001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】ミリコレ！～MILLIONLIVE COLLECTION～ 201707
# THEATER SHOW TIME☆
# 2017/07/14
# 2018/07/20
# https://cdn.img-conv.gamerch.com/img.gamerch.com/imasml-theater-wiki/1500009382001.jpg
# https://imasml-theater-wiki.gamerch.com/【イベント】THEATER SHOW TIME☆
#
# 2020-06-06 16:43:06.914938
# 2020-06-06 16:43:08.538031
# papara
